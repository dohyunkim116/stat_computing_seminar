# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## Objective
#
#    - Install Jupyter Notebook and be able to open it for later use
#    - Be familar with the syntax and shortkeys

# %% [markdown]
# ## Installation
# * In the terminal type:
#     - `conda install -c conda-forge notebook`
#     - `pip install notebook`
#
# Alternatively, you could get by using Binder: https://mybinder.org/v2/gh/dophos/stat_computing_seminar/455717d6c415d42156e5bba39aea12bf5c334af8
#
# ### Make R kernel available to use in Jupyter
# 1. Install R package, IRkernel. `install.packages("IRkernel")`
# 2. Start the R from the terminal and type `IRkernel::installspec()`
#
# ### Install Julia (sometime before Intro to Julia session)
# * Follow the instruction in Section 1.3 at https://www.softcover.io/read/7b8eb7d0/juliabook/introduction

# %% [markdown]
# ## Markdown syntax
#
# * Press `M` to enter markdown mode
# * Learn as you document your own project or meeting note by googling as needed. But here are things that are often used.
#
# ### Bullet points
#
#    * bullet point 1
#    * bullet point 2
#        * bullet point 21
#        * bullet point 22
#            * bullet point 221
#            * bullet point 222
#
# ### Numbered lists
#
#    1. one
#    2. two
#
# ### Emphasis
#    * Bold: **string** or __string__
#    * Italic: *string* or _string_
#
# ### Text for code
#    * This is an inline `code`.
#    * This is a code block:
#        ```
#        line 1
#        line 2
#        line 3
#        ```

# %% [markdown]
# ## Code Block
#
# * Press `Y` to enter code mode

# %%
d1 <- rnorm(100)
hist(d1)
# Out:
# Plot with title “Histogram of d1”

# %%
d2 <- rbeta(100,1,1)
hist(d2)
# Out:
# Plot with title “Histogram of d2”
