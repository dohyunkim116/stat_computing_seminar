# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## Objective
#
#    - Install Jupyter Notebook and be able to open it for later use
#    - Be familar with the syntax and shortkeys

# %% [markdown]
# ## Installation
#
# * Using Anaconda command line installer (***UPDATED ON 06-28-2020***)
#    1. Go to https://www.anaconda.com/products/individual and choose the command-line install for your OS
#    2. Go to https://docs.anaconda.com/anaconda/install/mac-os/ and scroll down to follw the instruction titled "Using the command-line install." (***For Mac users***)
# * In the terminal type:
#     * Using Python
#         * Python 2 (will be defunct soon)
#         * Python 3
#             1. `pip3 install --upgrade pip`
#             2. `pip3 install jupyter`
#             3. If installation was successful type: `jupyter notebook`
#
# Alternatively, you could get by using Binder: https://mybinder.org/v2/gh/dophos/stat_computing_seminar.git/master
#
# ### Make R kernel available for Jupyter Notebook
# 1. Install R package, IRkernel. `install.packages("IRkernel")`
# 2. Start the R from the terminal and type `IRkernel::installspec()`
#
# ### Install Julia (sometime before Intro to Julia session)
# * Follow the instruction in Section 1.3 at https://www.softcover.io/read/7b8eb7d0/juliabook/introduction

# %% [markdown]
# ## Markdown syntax
#
# * Press `M` to enter markdown mode
# * Best learned as you document your own project or meeting note by googling as needed. But here are things that are often used.
#
# ### Bullet points
#
#    * bullet point 1
#    * bullet point 2
#        * bullet point 21
#        * bullet point 22
#            * bullet point 221
#            * bullet point 222
#
# ### Numbered lists
#
#    1. one
#    2. two
#
# ### Emphasis
#    * Bold: **string** or __string__
#    * Italic: *string* or _string_
#
# ### Text for code
#    * This is an inline `code`.
#    * This is a code block:
#        ```
#        line 1
#        line 2
#        line 3
#        ```
#
# ### Latex
#    $x + y = 2$

# %% [markdown]
# ## Code Block
#
# * Press `Y` to enter code mode

# %% [markdown]
# ### I am sampling from normal distribution 100 times, and making a histogram.

# %%
d1 <- rnorm(100)
hist(d1)
# Out:
# Plot with title “Histogram of d1”

# %%
d2 <- rbeta(100,1,1)
hist(d2)
# Out:
# Plot with title “Histogram of d2”
